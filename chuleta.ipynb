# %% [markdown]
# # Martin Mihailov
# ## “Mi chuleta de Markdown”.
# Lista viñetas
# - **juan 4:24**
# - *Dios es espíritu, y los que lo adoran deben adorarle en espíritu y en verdad.*
#
# 1. Extension PYTHON
# 2. codigo print("hola universo")
# 3. Ejecutar
#
# Lista comandos:
# - **if**
# - **for**
# - **print**
#
# >Cosejo utiles:
# >>Actitud y utilizar las herramientas adecuadas
# Codigo Python:
# ```python
#  print ("hola universo")
#  ```

# %%
print("HOLA UNIVERSO")
# Out:
# HOLA UNIVERSO

# %% [markdown]
# |Comando|Funcion|
# |--------|-------|
# |print("")|imprime texto|

# %% [markdown]
# # Mi primer programa en Python
# Este es mi primer *Hola Mundo* en un Jupyter Notebook.
# Voy a escribir una instrucción en Python y ver el resultado.

# %%
print("hola universo")
# Out:
# hola universo

# %% [markdown]
# # Pidiendo datos al usuario
# Ahora vamos a hacer un programa que pregunte tu nombre
# y luego te salude de manera personalizada.

# %%
nombre = input("¿Cómo te llamas? ")
print("Encantado de conocerte,", nombre)
# Out:
# Encantado de conocerte, martin

# %% [markdown]
# # Suma de dos números
# Ahora vamos a escribir un programa en Python que pida dos números
# y muestre el resultado de sumarlos.
# Los decimales los introduzco con un punto.
# Ejm: 4.3 y 3,6

# %%
num1 = float(input("Introduce el primer número: "))
num2 = float(input("Introduce el segundo número: "))

resultado = num1 + num2
print("La suma es:", resultado)
# Out:
# La suma es: 4.0
