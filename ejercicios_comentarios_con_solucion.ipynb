# %% [markdown]
# # Ejercicios sobre Comentarios en Python
# Este notebook contiene **5 ejercicios** para practicar cómo escribir comentarios en Python:
# - Comentarios de una sola línea (`#`)
# - Comentarios al final de línea
# - Comentarios en varias líneas
# - Docstrings (`""" ... """`)
# - Desactivar código comentándolo.
#
# > Intenta resolver cada ejercicio añadiendo tus propios comentarios.

# %% [markdown]
# ## 1️⃣ Añadir comentarios descriptivos
# **Enunciado:**
# El siguiente código no tiene ninguna explicación. Añade **comentarios con `#`** para que quede claro qué hace cada línea.
# ```python
# x = 8
# y = 3
# print(x * y)
# ```

# %%
# Escribe aquí tu solución
x = 8 # x le da el valor 8
y = 3 # y le da el valor 3
print (x * y) #imprime por pantalla lo que esta dentro del print y le asigna los valores que le hemos puesto multiplicandolos
# Out:
# 24

# %% [markdown]
# ## 2️⃣ Comentario al final de la línea
# **Enunciado:**
# Agrega un comentario al final de cada instrucción explicando su función.
# ```python
# a = 5
# b = 2
# print(a / b)
# ```

# %%
# Escribe aquí tu solución
x = 5 # x le da el valor 5
y = 2 # y le da el valor 2
print(x / y) #imprime por pantalla lo que esta dentro del print y le asigna los valores que le hemos puesto dividiendolos
# Out:
# 2.5

# %% [markdown]
# ## 3️⃣ Explicación en varias líneas
# **Enunciado:**
# Escribe un **comentario de varias líneas con `#`** al inicio que explique lo que hace este programa.
# ```python
# nombre = input("Introduce tu nombre: ")
# print("Hola", nombre)
# ```

# %%
# Escribe aquí tu solución
nombre = input("Introduce tu nombre: ")#Pide al usuario que escriba tu nombre por teclado.
print("hola" ,nombre)#Despues de escribir el texto se guarda en la variable llamada nombre y te imprime por pantalla el "hola" que lo acompaña

# %% [markdown]
# ## 4️⃣ Docstring en función
# **Enunciado:**
# Completa el **docstring** de esta función para explicar qué hace y qué devuelve.
# ```python
# def cuadrado(n):
#     return n ** 2
# ```

# %%
def cuadrado(n):
    """
    Calcula el cuadrado de un numero.
    parametros:
    n--numero a elevar al cuadrado
    devuelve:
    el resultado de la n al cuadrado 
    """
    return 5 ** 2
print(cuadrado("n"))
help (cuadrado)
# Out:
# 25

# %%
# Escribe aquí tu solución
def #se usa para definir una funcion
cuadrado #es el nombre de la funcion
(n) #indica un valor que tu le das 
return #devuelve el valor que has definido previamente
n ** 2 #n es el parametro y ** es el parametro al cuadrado

# %% [markdown]
# ## 5️⃣ Eliminar un `print` sin borrarlo
# **Enunciado:**
# Desactiva la segunda línea del siguiente código usando un comentario, de forma que no se ejecute.
# ```python
# print("Hola")
# print("Esto no debe verse")
# print("Adiós")
# ```

# %%
# Escribe aquí tu solución
#
print("Hola")
#print("Esto no debe verse")
print("Adiós")
# Out:
# Hola
# Adiós
